# %%
from IPython.display import HTML
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

import urllib2
import bs4
import time
import operator
import re 
    
# %matplotlib inline
import seaborn as sns

# %%
#Time Series Data
#UR = pd.read_csv('UnempRate.csv', sep=',')
crime = pd.read_csv('violent_crime_count_age17andup.csv', sep=',', na_values=[" ", ""])
#prescription = pd.read_csv('prescription_rate.csv', sep=',', na_values=[" ", ""])
#population = pd.read_csv('population.csv', sep=',', na_values=[" ", ""])
# birth_rate = pd.read_csv('birth_rate.csv', sep=',', na_values=[" ", ""])
# death_rate = pd.read_csv('death_rate.csv', sep=',', na_values=[" ", ""])

# %%
#Non-Time Series Data
data = pd.read_csv('cleaned_GaCountiesODDeath.csv', na_values=[" ", ""] ,sep=',', index_col=0)
normalized_data = data/population

hospital = pd.read_csv('cleaned_GaHospitals.csv', na_values=[" ", ""] ,sep=',', index_col=0).fillna(0)
dropbox = pd.read_csv('drug_dropbox.csv', na_values=[" ", ""] ,sep=',').fillna(0)
hospital=hospital.rename(columns = {'Count':'hospital_count'})
dropbox=dropbox.rename(columns = {'COUNT':'dropbox_count'})
dropbox=dropbox.rename(columns = {'24Availability':'dropbox_247availability'})

# %%
#data[['Counties','Rural', '2016', '1yrlag', '2yrlag', '10yrlag']]
normalized_data['1yrlag']=(normalized_data['2016']-normalized_data['2015'])/normalized_data['2015']
normalized_data['5yrlag']=(normalized_data['2016']-normalized_data['2011'])/normalized_data['2011']
normalized_data['10yrlag']=(normalized_data['2016']-normalized_data['2006'])/normalized_data['2006']
normalized_data=normalized_data.replace([np.inf, -np.inf], np.nan)
normalized_data = normalized_data.fillna(0)

# %%
df = normalized_data[['County','Rural', '1yrlag', '5yrlag', '10yrlag','2016']].copy()

# %%
df1 = pd.concat([df, hospital['hospital_count'], dropbox['dropbox_247availability'], dropbox['dropbox_count']], axis=1)

# %%
df1.head(10)
# Out:
#      County  Rural    1yrlag    5yrlag   10yrlag  2016  hospital_count  \
# 0   Appling      1  0.000000  0.000000  0.000000     3               0
# 1  Atkinson      1  0.000000  0.000000  0.000000     1               0
# 2     Bacon      1  0.000000 -1.000000 -1.000000     0               0
# 3     Baker      1 -1.000000  0.000000  0.000000     0               0
# 4     Banks      1  0.333333 -0.333333  3.000000     4               2
# 5  Ben Hill      1  0.000000  0.000000  0.000000     1               0
# 6   Berrien      1  0.000000  0.000000 -0.666667     1               1
# 7  Bleckley      1 -0.666667  0.000000  0.000000     1               1
# 8  Brantley      1  0.400000  0.000000  2.500000     7               1
# 9    Brooks      1  0.000000 -0.500000  0.000000     1               1
#
#    dropbox_247availability  dropbox_count
# 0                        1              1
# 1                        0              0
# 2                        0              1
# 3                        0              1
# 4                        1              1
# 5                        0              1
# 6                        0              2
# 7                        1              2
# 8                        1              1
# 9                        0              1

# %%
crime['1yrlag']=(crime['2016']-crime['2015'])/crime['2015']
crime['5yrlag']=(crime['2016']-crime['2011'])/crime['2011']
crime['10yrlag']=(crime['2016']-crime['2006'])/crime['2006']
# Out:
#             County  2001  2002  2003  2004  2005  2006  2007  2008  2009  \
# 